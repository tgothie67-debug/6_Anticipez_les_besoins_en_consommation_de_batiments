# %% [markdown]
# # Analyse Exploratoire

# %% [markdown]
# ### Import des modules

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import missingno as msno # librairie pour identifier les données manquantes
import statsmodels.api as sm

# %%
pd.set_option('display.max_columns', None)  # Affiche toutes les colonnes

pd.set_option('display.max_rows', None) # Affiche toutes les lignes

# %% [markdown]
# ### Analyse Exploratoire

# %%
building_consumption = pd.read_csv('data/2016_Building_Energy_Benchmarking.csv')

# %%
# On regarde comment un batiment est défini dans ce jeu de données 
building_consumption.head(1)
# Out:
#    OSEBuildingID  DataYear    BuildingType PrimaryPropertyType  \
# 0              1      2016  NonResidential               Hotel
#
#            PropertyName        Address     City State  ZipCode  \
# 0  Mayflower park hotel  405 Olive way  Seattle    WA  98101.0
#
#   TaxParcelIdentificationNumber  CouncilDistrictCode Neighborhood  Latitude  \
# 0                    0659000030                    7     DOWNTOWN   47.6122
#
#    Longitude  YearBuilt  NumberofBuildings  NumberofFloors  PropertyGFATotal  \
# 0 -122.33799       1927                1.0              12             88434
#
#    PropertyGFAParking  PropertyGFABuilding(s) ListOfAllPropertyUseTypes  \
# 0                   0                   88434                     Hotel
#
#   LargestPropertyUseType  LargestPropertyUseTypeGFA  \
# 0                  Hotel                    88434.0
#
#   SecondLargestPropertyUseType  SecondLargestPropertyUseTypeGFA  \
# 0                          NaN                              NaN
#
#   ThirdLargestPropertyUseType  ThirdLargestPropertyUseTypeGFA  \
# 0                         NaN                             NaN
#
#   YearsENERGYSTARCertified  ENERGYSTARScore  SiteEUI(kBtu/sf)  \
# 0                      NaN             60.0         81.699997
#
#    SiteEUIWN(kBtu/sf)  SourceEUI(kBtu/sf)  SourceEUIWN(kBtu/sf)  \
# 0           84.300003               182.5                 189.0
#
#    SiteEnergyUse(kBtu)  SiteEnergyUseWN(kBtu)  SteamUse(kBtu)  \
# 0            7226362.5              7456910.0       2003882.0
#
#    Electricity(kWh)  Electricity(kBtu)  NaturalGas(therms)  NaturalGas(kBtu)  \
# 0        1156514.25          3946027.0          12764.5293         1276453.0
#
#    DefaultData  Comments ComplianceStatus Outlier  TotalGHGEmissions  \
# 0        False       NaN        Compliant     NaN             249.98
#
#    GHGEmissionsIntensity
# 0                   2.83

# %%
# On regarde le nombre de valeurs manquantes par colonne ainsi que leur type 
# %matplotlib inline

# Afficher le type de chaque colonne
print("Types des colonnes :")
print(building_consumption.dtypes)

# Afficher la matrice de valeurs manquantes
nb_lines = building_consumption.shape[0]
msno.matrix(building_consumption.sample(nb_lines))
# Out:
# Types des colonnes :
# OSEBuildingID                        int64
# DataYear                             int64
# BuildingType                           str
# PrimaryPropertyType                    str
# PropertyName                           str
# Address                                str
# City                                   str
# State                                  str
# ZipCode                            float64
# TaxParcelIdentificationNumber          str
# CouncilDistrictCode                  int64
# Neighborhood                           str
# Latitude                           float64
# Longitude                          float64
# YearBuilt                            int64
# NumberofBuildings                  float64
# NumberofFloors                       int64
# PropertyGFATotal                     int64
# PropertyGFAParking                   int64
# PropertyGFABuilding(s)               int64
# ListOfAllPropertyUseTypes              str
# LargestPropertyUseType                 str
# LargestPropertyUseTypeGFA          float64
# SecondLargestPropertyUseType           str
# SecondLargestPropertyUseTypeGFA    float64
# ThirdLargestPropertyUseType            str
# ThirdLargestPropertyUseTypeGFA     float64
# YearsENERGYSTARCertified            object
# ENERGYSTARScore                    float64
# SiteEUI(kBtu/sf)                   float64
# SiteEUIWN(kBtu/sf)                 float64
# SourceEUI(kBtu/sf)                 float64
# SourceEUIWN(kBtu/sf)               float64
# SiteEnergyUse(kBtu)                float64
# SiteEnergyUseWN(kBtu)              float64
# SteamUse(kBtu)                     float64
# Electricity(kWh)                   float64
# Electricity(kBtu)                  float64
# NaturalGas(therms)                 float64
# NaturalGas(kBtu)                   float64
# DefaultData                           bool
# Comments                           float64
# ComplianceStatus                       str
# Outlier                                str
# TotalGHGEmissions                  float64
# GHGEmissionsIntensity              float64
# dtype: object
# <Axes: >

# %% [markdown]
# #### TERMINER L'ANALYSE EXPLORATOIRE

# %% [markdown]
# A réaliser :
# - Une analyse descriptive des données, y compris une explication du sens des colonnes gardées, des arguments derrière la suppression de lignes ou de colonnes, des statistiques descriptives et des visualisations pertinentes.

# %%
# Affiche tous les types de bâtiments
buildingtype_uniques = building_consumption['BuildingType'].unique()
df_uniques = pd.DataFrame(buildingtype_uniques, columns=['BuildingType'])
print(df_uniques)
# Out:
#            BuildingType
# 0        NonResidential
# 1    Nonresidential COS
# 2  Multifamily MR (5-9)
# 3     SPS-District K-12
# 4                Campus
# 5  Multifamily LR (1-4)
# 6  Multifamily HR (10+)
# 7     Nonresidential WA

# %%
# Afficher le nombre de lignes avant le filtre
print(f"Nombre de lignes avant le filtre : {len(building_consumption)}")

# Garder les lignes avec les bâtiments non destinés à l'habitation
# Liste des types de bâtiments non résidentiels
non_residentiel = [
    "NonResidential",
    "Nonresidential COS",
    "SPS-District K-12",
    "Campus",
    "Nonresidential WA"
]

# Filtrer le DataFrame
building_consumption_non_residentiel = building_consumption[
    building_consumption['BuildingType'].isin(non_residentiel)
]

# Afficher le nombre de lignes après le filtre
print(f"Nombre de lignes après le filtre : {len(building_consumption_non_residentiel)}")
# Out:
# Nombre de lignes avant le filtre : 3376
# Nombre de lignes après le filtre : 1668

# %%
# Supprimer les bâtiments considérés comme des outliers
# Afficher le nombre de lignes avant le filtre
print(f"Nombre de lignes avant le filtre : {len(building_consumption_non_residentiel)}")

# Filtrer pour garder les lignes où 'Outlier' est vide ou NaN
building_consumption_sans_outliers = building_consumption_non_residentiel[
    building_consumption_non_residentiel['Outlier'].isna()
]

# Afficher le nombre de lignes après le filtre
print(f"Nombre de lignes après le filtre : {len(building_consumption_sans_outliers)}")
# Out:
# Nombre de lignes avant le filtre : 1668
# Nombre de lignes après le filtre : 1651

# %%
# Garder les bâtiments conformes aux obligations réglementaires de reporting énergétique
# Afficher le nombre de lignes avant le filtre
print(f"Nombre de lignes avant le filtre : {len(building_consumption_sans_outliers)}")

# Filtrer pour garder les lignes où 'ComplianceStatus' est "Compliant" ou "Error - Correct Default Data"
building_consumption_compliant = building_consumption_sans_outliers[
    building_consumption_sans_outliers['ComplianceStatus'].isin(["Compliant", "Error - Correct Default Data"])
]

# Afficher le nombre de lignes après le filtre
print(f"Nombre de lignes après le filtre : {len(building_consumption_compliant)}")
# Out:
# Nombre de lignes avant le filtre : 1651
# Nombre de lignes après le filtre : 1634

# %%
colonnes_num = ['YearBuilt',
'Latitude',
'Longitude',
'NumberofBuildings',
'NumberofFloors',
'PropertyGFABuilding(s)',
'SiteEUI(kBtu/sf)',
'SiteEnergyUse(kBtu)',
'SteamUse(kBtu)',
'NaturalGas(therms)',
'TotalGHGEmissions',
'GHGEmissionsIntensity',
'ENERGYSTARScore']

# Matrice de corrélation
mask = np.triu(np.ones_like(building_consumption_compliant[colonnes_num].corr()))

# Heatmap général
plt.figure(figsize=(16, 6))
mask = np.triu(np.ones_like(building_consumption_compliant[colonnes_num].corr()))
heatmap = sns.heatmap(building_consumption_compliant[colonnes_num].corr(), mask=mask, vmin=-1, vmax=1, annot=True, cmap='coolwarm')
heatmap.set_title('Triangle de corrélation', fontdict={'fontsize':18}, pad=16)
# Out:
# Text(0.5, 1.0, 'Triangle de corrélation')

# %%
# Garder les colonnes pertinentes
building_consumption_cleaned = building_consumption_compliant[[
    'BuildingType',
    'Latitude',
    'Longitude',
    'YearBuilt',
    'NumberofBuildings',
    'NumberofFloors',
    'PropertyGFABuilding(s)',
    'ListOfAllPropertyUseTypes',
    'LargestPropertyUseType',
    'ENERGYSTARScore',
    'SiteEUI(kBtu/sf)',
    'SiteEnergyUse(kBtu)',
    'TotalGHGEmissions',
    'GHGEmissionsIntensity'
]]

# %%
building_consumption_cleaned.head(5)
# Out:
#      BuildingType  Latitude  Longitude  YearBuilt  NumberofBuildings  \
# 0  NonResidential  47.61220 -122.33799       1927                1.0
# 1  NonResidential  47.61317 -122.33393       1996                1.0
# 2  NonResidential  47.61393 -122.33810       1969                1.0
# 3  NonResidential  47.61412 -122.33664       1926                1.0
# 4  NonResidential  47.61375 -122.34047       1980                1.0
#
#    NumberofFloors  PropertyGFABuilding(s)      ListOfAllPropertyUseTypes  \
# 0              12                   88434                          Hotel
# 1              11                   88502     Hotel, Parking, Restaurant
# 2              41                  759392                          Hotel
# 3              10                   61320                          Hotel
# 4              18                  113580  Hotel, Parking, Swimming Pool
#
#   LargestPropertyUseType  ENERGYSTARScore  SiteEUI(kBtu/sf)  \
# 0                  Hotel             60.0         81.699997
# 1                  Hotel             61.0         94.800003
# 2                  Hotel             43.0         96.000000
# 3                  Hotel             56.0        110.800003
# 4                  Hotel             75.0        114.800003
#
#    SiteEnergyUse(kBtu)  TotalGHGEmissions  GHGEmissionsIntensity
# 0            7226362.5             249.98                   2.83
# 1            8387933.0             295.86                   2.86
# 2           72587024.0            2089.28                   2.19
# 3            6794584.0             286.43                   4.67
# 4           14172606.0             505.01                   2.88

# %%
# Liste des colonnes à analyser
colonnes = ['YearBuilt',
'NumberofBuildings',
'NumberofFloors',
'PropertyGFABuilding(s)',
'ENERGYSTARScore',
'SiteEUI(kBtu/sf)',
'SiteEnergyUse(kBtu)',
'TotalGHGEmissions',
'GHGEmissionsIntensity']

# Créer un boxplot pour chaque colonne
for colonne in colonnes:
    plt.figure(figsize=(4, 2))
    sns.boxplot(data=building_consumption_cleaned, y=colonne)
    plt.title(f"Boxplot de {colonne}")
    plt.show()

# %%
# Afficher le nombre de lignes avant suppression des outliers
nb_lignes_avant = len(building_consumption_cleaned)
print(f"Nombre de lignes avant suppression des outliers :  {nb_lignes_avant}\n")

# Fonction pour détecter et supprimer les outliers
def compter_supprimer_outliers(df, colonnes):
    outliers_counts = {}
    df_clean = df.copy()

    for colonne in colonnes:
        if colonne in df_clean.select_dtypes(include=[np.number]).columns:
            Q1 = df_clean[colonne].quantile(0.25)
            Q3 = df_clean[colonne].quantile(0.75)
            IQR = Q3 - Q1
            lower_bound = Q1 - 1.5 * IQR
            upper_bound = Q3 + 1.5 * IQR

            # Compter les outliers
            outliers = ((df_clean[colonne] < lower_bound) | (df_clean[colonne] > upper_bound))
            outliers_counts[colonne] = outliers.sum()

            # Supprimer les outliers
            df_clean = df_clean[~outliers]

    return outliers_counts, df_clean

# Utilisation
outliers_counts, building_consumption_sans_outliers = compter_supprimer_outliers(building_consumption_cleaned, colonnes)

# Afficher le nombre d'outliers par colonne
print("Nombre d'outliers par colonne :")
for colonne, count in outliers_counts.items():
    print(f"{colonne}: {count}")

# Afficher le nombre de lignes après suppression
nb_lignes_apres = len(building_consumption_sans_outliers)
print(f"\nNombre de lignes après suppression des outliers : {nb_lignes_apres}")
# Out:
# Nombre de lignes avant suppression des outliers :  1634
#
# Nombre d'outliers par colonne :
# YearBuilt: 0
# NumberofBuildings: 104
# NumberofFloors: 130
# PropertyGFABuilding(s): 131
# ENERGYSTARScore: 0
# SiteEUI(kBtu/sf): 121
# SiteEnergyUse(kBtu): 87
# TotalGHGEmissions: 58
# GHGEmissionsIntensity: 39
#
# Nombre de lignes après suppression des outliers : 964

# %%
# Créer un boxplot pour chaque colonne
for colonne in colonnes:
    plt.figure(figsize=(4, 2))
    sns.boxplot(data=building_consumption_sans_outliers, y=colonne)
    plt.title(f"Boxplot de {colonne}")
    plt.show()

# %%
# Supprime la colonne 'NumberofBuildings' car uniquement une valeur
building_consumption_sans_outliers = building_consumption_sans_outliers.drop(columns=['NumberofBuildings'])

# %%
# Ajout de l'âge du bâtiment
data_year = 2016
building_consumption_sans_outliers["BuildingAge"] = data_year - building_consumption_sans_outliers["YearBuilt"]

# Croissement entre l'âge et la surface (grand et ancien = plus énergivore ?)
building_consumption_sans_outliers["Age_x_Size"] = building_consumption_sans_outliers["BuildingAge"] * building_consumption_sans_outliers["PropertyGFABuilding(s)"]

# Surface par étage
building_consumption_sans_outliers["Floor_density"] = building_consumption_sans_outliers["PropertyGFABuilding(s)"] / building_consumption_sans_outliers["NumberofFloors"]

# Surface x étage
building_consumption_sans_outliers["Energy_per_floor"] = building_consumption_sans_outliers["PropertyGFABuilding(s)"] * building_consumption_sans_outliers["NumberofFloors"]

# %%
# Supprime les colonnes non pertinentes
building_consumption_sans_outliers = building_consumption_sans_outliers.drop(columns=['BuildingType', 'YearBuilt'])

# %%
# ENCODAGE DES VARIABLES CATÉGORIELLES

# Surface moyenne par type de bâtiment
mean_size_by_type = building_consumption_sans_outliers.groupby("LargestPropertyUseType")["PropertyGFABuilding(s)"].mean()
building_consumption_sans_outliers["size_x_type_mean"] = building_consumption_sans_outliers["LargestPropertyUseType"].map(mean_size_by_type)

# Nombre de type d'usage dans un bâtiment
building_consumption_sans_outliers['NumberOfPropertyUseTypes'] = building_consumption_sans_outliers['ListOfAllPropertyUseTypes'].str.split(',').str.len()

# Supprime la variable catégorielle brute
building_consumption_sans_outliers = building_consumption_sans_outliers.drop(columns=['LargestPropertyUseType', 'ListOfAllPropertyUseTypes'])

# %%
# Transformation logarithmique sur la colonne 'Age_x_Size' pour éviter les outliers
building_consumption_sans_outliers["Log_Age_x_Size"] = np.log(building_consumption_sans_outliers["Age_x_Size"])

# %%
building_consumption_sans_outliers.head(5)
# Out:
#     Latitude  Longitude  NumberofFloors  PropertyGFABuilding(s)  \
# 22  47.54576 -122.26853               2                   56228
# 23  47.65959 -122.31755               6                   58006
# 25  47.61500 -122.33081               2                   67224
# 34  47.66172 -122.29598               2                  110356
# 37  47.65671 -122.39047               2                   54986
#
#     ENERGYSTARScore  SiteEUI(kBtu/sf)  SiteEnergyUse(kBtu)  TotalGHGEmissions  \
# 22             95.0         26.100000         1.539478e+06              38.53
# 23             84.0         63.200001         3.663534e+06              90.01
# 25              NaN         19.500000         1.310237e+06               9.13
# 34              NaN         12.100000         3.183648e+05               3.93
# 37             97.0         30.000000         1.650279e+06              31.47
#
#     GHGEmissionsIntensity  BuildingAge  Age_x_Size  Floor_density  \
# 22                   0.69           55     3092540   28114.000000
# 23                   1.02           15      870090    9667.666667
# 25                   0.14           86     5781264   33612.000000
# 34                   0.04           61     6731716   55178.000000
# 37                   0.57           26     1429636   27493.000000
#
#     Energy_per_floor  size_x_type_mean  NumberOfPropertyUseTypes  \
# 22            112456      53068.446809                         1
# 23            348036      43827.933333                         2
# 25            134448      49994.000000                         1
# 34            220712      51170.750000                         1
# 37            109972      53068.446809                         1
#
#     Log_Age_x_Size
# 22       14.944503
# 23       13.676352
# 25       15.570133
# 34       15.722341
# 37       14.172930

# %%
# Nombre de valeurs vides (NaN) dans la colonne ENERGYSTARScore
nb_vide = building_consumption_compliant['ENERGYSTARScore'].isna().sum()

print("Nombre de valeurs vides dans ENERGYSTARScore :", nb_vide)
# Out:
# Nombre de valeurs vides dans ENERGYSTARScore : 551

# %%
# Variables explicatives
features = ['PropertyGFABuilding(s)',
'SiteEUI(kBtu/sf)',
'SiteEnergyUse(kBtu)',
'TotalGHGEmissions',
'GHGEmissionsIntensity',
'BuildingAge',
'Floor_density',
'Energy_per_floor',
'size_x_type_mean',
'NumberOfPropertyUseTypes',
'Log_Age_x_Size']

# Matrice de corrélation
mask = np.triu(np.ones_like(building_consumption_sans_outliers[features].corr()))

# Heatmap général
plt.figure(figsize=(16, 6))
mask = np.triu(np.ones_like(building_consumption_sans_outliers[features].corr()))
heatmap = sns.heatmap(building_consumption_sans_outliers[features].corr(), mask=mask, vmin=-1, vmax=1, annot=True, cmap='coolwarm')
heatmap.set_title('Triangle de corrélation', fontdict={'fontsize':18}, pad=16)
# Out:
# Text(0.5, 1.0, 'Triangle de corrélation')

# %%
# Remplacer les infinis par NaN
building_consumption_sans_outliers = building_consumption_sans_outliers.replace([np.inf, -np.inf], np.nan)

# Supprimer toutes les lignes contenant des NaN
building_consumption_sans_outliers = building_consumption_sans_outliers.dropna()

# Séparer les données avec ENERGYSTARScore connu
train_df = building_consumption_sans_outliers[building_consumption_sans_outliers["ENERGYSTARScore"].notna()]



X = train_df[features]
y = train_df["ENERGYSTARScore"]

# Ajouter une constante (intercept)
X_sm = sm.add_constant(X)

# Modèle OLS (régression linéaire)
model = sm.OLS(y, X_sm).fit()

print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        ENERGYSTARScore   R-squared:                       0.322
# Model:                            OLS   Adj. R-squared:                  0.311
# Method:                 Least Squares   F-statistic:                     27.63
# Date:                Fri, 13 Mar 2026   Prob (F-statistic):           2.44e-47
# Time:                        09:57:56   Log-Likelihood:                -2948.4
# No. Observations:                 651   AIC:                             5921.
# Df Residuals:                     639   BIC:                             5975.
# Df Model:                          11
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                       74.3244     36.776      2.021      0.044       2.109     146.540
# PropertyGFABuilding(s)       0.0001      0.000      1.047      0.295      -0.000       0.000
# SiteEUI(kBtu/sf)            -0.7684      0.080     -9.585      0.000      -0.926      -0.611
# SiteEnergyUse(kBtu)      -9.895e-07   1.87e-06     -0.529      0.597   -4.66e-06    2.68e-06
# TotalGHGEmissions            0.2112      0.088      2.408      0.016       0.039       0.383
# GHGEmissionsIntensity       -0.2053      3.523     -0.058      0.954      -7.124       6.713
# BuildingAge                 -0.0107      0.069     -0.155      0.877      -0.146       0.125
# Floor_density               -0.0004      0.000     -3.214      0.001      -0.001      -0.000
# Energy_per_floor          8.409e-06   2.03e-05      0.414      0.679   -3.15e-05    4.83e-05
# size_x_type_mean             0.0002      0.000      1.413      0.158   -8.39e-05       0.001
# NumberOfPropertyUseTypes     2.5806      1.397      1.847      0.065      -0.163       5.324
# Log_Age_x_Size               0.6016      2.886      0.208      0.835      -5.066       6.270
# ==============================================================================
# Omnibus:                       70.566   Durbin-Watson:                   2.128
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               91.230
# Skew:                          -0.871   Prob(JB):                     1.55e-20
# Kurtosis:                       3.571   Cond. No.                     9.33e+07
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 9.33e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score, mean_squared_error

X = train_df[features]
y = train_df["ENERGYSTARScore"]

X_tr, X_te, y_tr, y_te = train_test_split(
    X, y, test_size=0.3, random_state=42
)

rf_model = RandomForestRegressor(
    n_estimators=500,
    random_state=42,
    n_jobs=-1
)

rf_model.fit(X_tr, y_tr)

y_pred_tr = rf_model.predict(X_tr)
y_pred_te = rf_model.predict(X_te)

r2_tr = r2_score(y_tr, y_pred_tr)
rmse_tr = np.sqrt(mean_squared_error(y_tr, y_pred_tr))

r2_te = r2_score(y_te, y_pred_te)
rmse_te = np.sqrt(mean_squared_error(y_te, y_pred_te))

print(f"Train : R²={r2_tr:.3f} | RMSE={rmse_tr:.2f}")
print(f"Test  : R²={r2_te:.3f} | RMSE={rmse_te:.2f}")
# Out:
# Train : R²=0.916 | RMSE=8.00
# Test  : R²=0.426 | RMSE=19.79

# %%
# Nombre de valeurs vides (NaN) dans la colonne ENERGYSTARScore
nb_vide = building_consumption_sans_outliers['ENERGYSTARScore'].isna().sum()

print("Nombre de valeurs vides dans ENERGYSTARScore :", nb_vide)
# Out:
# Nombre de valeurs vides dans ENERGYSTARScore : 309

# %%
# Afficher le nombre de lignes avant suppression
nb_lignes_avant = len(building_consumption_sans_outliers)
print(f"Nombre de lignes avant suppression des valeurs vides : {nb_lignes_avant}")

# Supprimer les lignes avec des valeurs vides dans n'importe quelle colonne
building_consumption_cleaned = building_consumption_sans_outliers.dropna()

# Afficher le nombre de lignes après suppression
nb_lignes_apres = len(building_consumption_cleaned)
print(f"Nombre de lignes après suppression des valeurs vides : {nb_lignes_apres}")
# Out:
# Nombre de lignes avant suppression des valeurs vides : 964
# Nombre de lignes après suppression des valeurs vides : 653

# %%
# Exporter le DataFrame en CSV
building_consumption_cleaned.to_csv('data/building_consumption_cleaned.csv', index=False)

# %% [markdown]
# # Modélisation

# %% [markdown]
# ### Import des modules

# %%
#Selection
from sklearn.model_selection import (
    train_test_split,
    GridSearchCV, 
    cross_validate,
)
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error 
from sklearn.inspection import permutation_importance

#Preprocess
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, StandardScaler

#Modèles
from sklearn.dummy import DummyRegressor
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor

# %% [markdown]
# ### Feature Engineering

# %% [markdown]
# A réaliser : Enrichir le jeu de données actuel avec de nouvelles features issues de celles existantes.

# %%
building_consumption_cleaned.head(5)
# Out:
#          BuildingType  Latitude  Longitude  YearBuilt  NumberofFloors  \
# 22  SPS-District K-12  47.54576 -122.26853       1961               2
# 23     NonResidential  47.65959 -122.31755       2001               6
# 29     NonResidential  47.61558 -122.34186       1978               5
# 37  SPS-District K-12  47.65671 -122.39047       1990               2
# 39     NonResidential  47.66587 -122.38476       1961               2
#
#     PropertyGFABuilding(s)           ListOfAllPropertyUseTypes  \
# 22                   56228                         K-12 School
# 23                   58006                      Hotel, Parking
# 29                   52210                               Hotel
# 37                   54986                         K-12 School
# 39                   94900  Non-Refrigerated Warehouse, Office
#
#    LargestPropertyUseType  ENERGYSTARScore  SiteEnergyUse(kBtu)  \
# 22            K-12 School             95.0           1539478.50
# 23                  Hotel             84.0           3663534.50
# 29                  Hotel             57.0           4456714.50
# 37            K-12 School             97.0           1650279.25
# 39                 Office             57.0           6186461.50
#
#     TotalGHGEmissions
# 22              38.53
# 23              90.01
# 29             128.44
# 37              31.47
# 39             130.56

# %%
# Ajout de l'âge du bâtiment
data_year = 2016
building_consumption_cleaned["BuildingAge"] = data_year - building_consumption_cleaned["YearBuilt"]

# Croissement entre l'âge et la surface (grand et ancien = plus énergivore ?)
building_consumption_cleaned["Age_x_Size"] = building_consumption_cleaned["BuildingAge"] * building_consumption_cleaned["PropertyGFABuilding(s)"]

# Surface par étage
building_consumption_cleaned["Floor_density"] = building_consumption_cleaned["PropertyGFABuilding(s)"] / building_consumption_cleaned["NumberofFloors"]

# Surface x étage
building_consumption_cleaned["Energy_per_floor"] = building_consumption_cleaned["PropertyGFABuilding(s)"] * building_consumption_cleaned["NumberofFloors"]

# %%
# Supprime les colonnes non pertinentes
building_consumption_features = building_consumption_cleaned.drop(columns=['BuildingType', 'YearBuilt'])

# %%
# Exporter le DataFrame en CSV
building_consumption_features.to_csv('data/building_consumption_features.csv', index=False)

# %% [markdown]
# ### Préparation des features pour la modélisation

# %% [markdown]
# A réaliser :
# * Si ce n'est pas déjà fait, supprimer toutes les colonnes peu pertinentes pour la modélisation.
# * Tracer la distribution de la cible pour vous familiariser avec l'ordre de grandeur. En cas d'outliers, mettez en place une démarche pour les supprimer.
# * Débarrassez-vous des features redondantes en utilisant une matrice de corrélation.
# * Réalisez différents graphiques pour comprendre le lien entre vos features et la target (boxplots, scatterplots, pairplot si votre nombre de features numériques n'est pas très élevé).
# *  Séparez votre jeu de données en un Pandas DataFrame X (ensemble de feautures) et Pandas Series y (votre target).
# * Si vous avez des features catégorielles, il faut les encoder pour que votre modèle fonctionne.

# %%
# ENCODAGE DES VARIABLES CATÉGORIELLES

# Surface moyenne par type de bâtiment
mean_size_by_type = building_consumption_features.groupby("LargestPropertyUseType")["PropertyGFABuilding(s)"].mean()
building_consumption_features["size_x_type_mean"] = building_consumption_features["LargestPropertyUseType"].map(mean_size_by_type)

# Nombre de type d'usage dans un bâtiment
building_consumption_features['NumberOfPropertyUseTypes'] = building_consumption_features['ListOfAllPropertyUseTypes'].str.split(',').str.len()

# Supprime la variable catégorielle brute
building_consumption_features = building_consumption_features.drop(columns=['LargestPropertyUseType', 'ListOfAllPropertyUseTypes'])

# %%
# Transformation logarithmique sur la colonne 'Age_x_Size' pour éviter les outliers
building_consumption_features["Log_Age_x_Size"] = np.log(building_consumption_features["Age_x_Size"])

# %%
colonnes = ['NumberofFloors', 'PropertyGFABuilding(s)', 'ENERGYSTARScore',
       'SiteEnergyUse(kBtu)', 'TotalGHGEmissions', 'BuildingAge',
       'Log_Age_x_Size', 'Floor_density', 'Energy_per_floor','size_x_type_mean', 'NumberOfPropertyUseTypes']

# Matrice de corrélation
mask = np.triu(np.ones_like(building_consumption_features[colonnes].corr()))

# Heatmap général
plt.figure(figsize=(16, 6))
mask = np.triu(np.ones_like(building_consumption_features[colonnes].corr()))
heatmap = sns.heatmap(building_consumption_features[colonnes].corr(), mask=mask, vmin=-1, vmax=1, annot=True, cmap='coolwarm')
heatmap.set_title('Triangle de corrélation', fontdict={'fontsize':18}, pad=16)
# Out:
# Text(0.5, 1.0, 'Triangle de corrélation')

# %%
# Créer un boxplot pour chaque colonne
for colonne in colonnes:
    plt.figure(figsize=(8, 6))
    sns.boxplot(data=building_consumption_features, y=colonne)
    plt.title(f"Boxplot de {colonne}")
    plt.show()

# %%
# Afficher le nombre de lignes avant suppression des outliers
nb_lignes_avant = len(building_consumption_features)
print(f"Nombre de lignes avant suppression des outliers :  {nb_lignes_avant}\n")

# Fonction pour détecter et supprimer les outliers
def compter_supprimer_outliers(df, colonnes):
    outliers_counts = {}
    df_clean = df.copy()

    for colonne in colonnes:
        if colonne in df_clean.select_dtypes(include=[np.number]).columns:
            Q1 = df_clean[colonne].quantile(0.25)
            Q3 = df_clean[colonne].quantile(0.75)
            IQR = Q3 - Q1
            lower_bound = Q1 - 1.5 * IQR
            upper_bound = Q3 + 1.5 * IQR

            # Compter les outliers
            outliers = ((df_clean[colonne] < lower_bound) | (df_clean[colonne] > upper_bound))
            outliers_counts[colonne] = outliers.sum()

            # Supprimer les outliers
            df_clean = df_clean[~outliers]

    return outliers_counts, df_clean

# Utilisation
outliers_counts, building_consumption_features_sans_outliers = compter_supprimer_outliers(building_consumption_features, colonnes)

# Afficher le nombre d'outliers par colonne
print("Nombre d'outliers par colonne :")
for colonne, count in outliers_counts.items():
    print(f"{colonne}: {count}")

# Afficher le nombre de lignes après suppression
nb_lignes_apres = len(building_consumption_features_sans_outliers)
print(f"\nNombre de lignes après suppression des outliers : {nb_lignes_apres}")
# Out:
# Nombre de lignes avant suppression des outliers :  706
#
# Nombre d'outliers par colonne :
# NumberofFloors: 16
# PropertyGFABuilding(s): 33
# ENERGYSTARScore: 0
# SiteEnergyUse(kBtu): 33
# TotalGHGEmissions: 20
# BuildingAge: 0
# Log_Age_x_Size: 15
# Floor_density: 24
# Energy_per_floor: 47
# size_x_type_mean: 75
# NumberOfPropertyUseTypes: 4
#
# Nombre de lignes après suppression des outliers : 439

# %%
building_consumption_features.head(3)
# Out:
#     Latitude  Longitude  NumberofFloors  PropertyGFABuilding(s)  \
# 22  47.54576 -122.26853               2                   56228
# 23  47.65959 -122.31755               6                   58006
# 29  47.61558 -122.34186               5                   52210
#
#     ENERGYSTARScore  SiteEnergyUse(kBtu)  TotalGHGEmissions  BuildingAge  \
# 22             95.0            1539478.5              38.53           55
# 23             84.0            3663534.5              90.01           15
# 29             57.0            4456714.5             128.44           38
#
#     Age_x_Size  Floor_density  Energy_per_floor  size_x_type_mean  \
# 22     3092540   28114.000000            112456      52669.673684
# 23      870090    9667.666667            348036      46882.650000
# 29     1983980   10442.000000            261050      46882.650000
#
#     NumberOfPropertyUseTypes  Log_Age_x_Size
# 22                         1       14.944503
# 23                         2       13.676352
# 29                         1       14.500615

# %%
building_consumption_features_sans_outliers = building_consumption_features_sans_outliers.dropna()

# %%
# Dataframe pour les features
df_features = building_consumption_features_sans_outliers[['Latitude',
                                            'Longitude',
                                            'NumberofFloors',
                                            'PropertyGFABuilding(s)',
                                            'ENERGYSTARScore',
                                            'BuildingAge',
                                            'Floor_density',
                                            'Energy_per_floor',
                                            'size_x_type_mean',
                                            'NumberOfPropertyUseTypes',
                                            'Log_Age_x_Size']]
# Dataframe pour la target du modèle "Energy"
df_energy_target = building_consumption_features_sans_outliers[['SiteEnergyUse(kBtu)']]

# Dataframe pour la target du modèle "CO2"
df_ghg_target = building_consumption_features_sans_outliers[['TotalGHGEmissions']]

# %%
# Liste des DataFrames et des noms de fichiers correspondants
dataframes_to_export = [
    (df_features, 'data/features.csv'),
    (df_energy_target, 'data/energy_target.csv'),
    (df_ghg_target, 'data/ghg_target.csv')
]

# Boucle pour exporter chaque DataFrame
for df, file_path in dataframes_to_export:
    df.to_csv(file_path, index=False)
